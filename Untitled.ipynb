# %%
from fbprophet import Prophet

# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/BeerWineLiquor.csv')

# %%
df.head()
# Out:
#        date  beer
# 0  1/1/1992  1509
# 1  2/1/1992  1541
# 2  3/1/1992  1597
# 3  4/1/1992  1675
# 4  5/1/1992  1822

# %%
df.columns = ['ds','y']

# %%
df['ds'] = pd.to_datetime(df['ds'])

# %%
m = Prophet()
m.fit(df)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=24,freq='MS')

# %%
future.tail()
# Out:
#             ds
# 343 2020-08-01
# 344 2020-09-01
# 345 2020-10-01
# 346 2020-11-01
# 347 2020-12-01

# %%
forecast = m.predict(future)

# %%
forecast.head()
# Out:
#           ds        trend   yhat_lower   yhat_upper  trend_lower  trend_upper  \
# 0 1992-01-01  1778.715353  1147.536393  1485.941135  1778.715353  1778.715353
# 1 1992-02-01  1781.314460  1188.614575  1515.286241  1781.314460  1781.314460
# 2 1992-03-01  1783.745882  1443.569424  1769.508968  1783.745882  1783.745882
# 3 1992-04-01  1786.344989  1430.225668  1743.446764  1786.344989  1786.344989
# 4 1992-05-01  1788.860254  1675.990136  1996.657200  1788.860254  1788.860254
#
#    additive_terms  additive_terms_lower  additive_terms_upper      yearly  \
# 0     -462.190276           -462.190276           -462.190276 -462.190276
# 1     -428.338761           -428.338761           -428.338761 -428.338761
# 2     -179.583331           -179.583331           -179.583331 -179.583331
# 3     -196.439274           -196.439274           -196.439274 -196.439274
# 4       45.228728             45.228728             45.228728   45.228728
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0   -462.190276   -462.190276                   0.0
# 1   -428.338761   -428.338761                   0.0
# 2   -179.583331   -179.583331                   0.0
# 3   -196.439274   -196.439274                   0.0
# 4     45.228728     45.228728                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 0                         0.0                         0.0  1316.525077
# 1                         0.0                         0.0  1352.975698
# 2                         0.0                         0.0  1604.162551
# 3                         0.0                         0.0  1589.905715
# 4                         0.0                         0.0  1834.088982

# %%
forecast.columns
# Out:
# Index(['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper',
#        'additive_terms', 'additive_terms_lower', 'additive_terms_upper',
#        'yearly', 'yearly_lower', 'yearly_upper', 'multiplicative_terms',
#        'multiplicative_terms_lower', 'multiplicative_terms_upper', 'yhat'],
#       dtype='object')

# %%
forecast[['ds','yhat_lower', 'yhat_upper','yhat']].tail(12)
# Out:
#             ds   yhat_lower   yhat_upper         yhat
# 336 2020-01-01  4469.616787  4789.985218  4630.451471
# 337 2020-02-01  4518.966945  4849.963546  4680.440893
# 338 2020-03-01  4790.876056  5097.973942  4944.293075
# 339 2020-04-01  4782.689403  5115.648916  4943.575038
# 340 2020-05-01  5042.661030  5374.465945  5200.860370
# 341 2020-06-01  5029.272951  5348.685780  5182.420269
# 342 2020-07-01  5163.296744  5468.228981  5315.399291
# 343 2020-08-01  5083.081873  5415.786823  5244.478832
# 344 2020-09-01  4923.542193  5244.700894  5087.555902
# 345 2020-10-01  5033.653633  5350.242842  5192.266221
# 346 2020-11-01  5181.248647  5500.475645  5337.343793
# 347 2020-12-01  6176.114987  6506.213447  6339.188526

# %%
pd.plotting.register_matplotlib_converters()

# %%
import matplotlib.pyplot as plt
m.plot(forecast)
plt.xlim('2014-01-01','2022-01-01')
# Out:
# (735234.0, 738156.0)

# %%
forecast.plot(x='ds',y='yhat',figsize=(15,8))

# %%
m.plot_components(forecast);
